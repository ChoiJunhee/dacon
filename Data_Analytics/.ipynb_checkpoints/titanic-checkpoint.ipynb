# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv('./titanic/train.csv')
test_df = pd.read_csv('./titanic/test.csv')
submission = pd.read_csv('./titanic/gender_submission.csv')

# %%
train_df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('ggplot')

# %%
train_df[['Age', 'Cabin', 'Embarked']]
# Out:
#       Age Cabin Embarked
# 0    22.0   NaN        S
# 1    38.0   C85        C
# 2    26.0   NaN        S
# 3    35.0  C123        S
# 4    35.0   NaN        S
# ..    ...   ...      ...
# 886  27.0   NaN        S
# 887  19.0   B42        S
# 888   NaN   NaN        S
# 889  26.0  C148        C
# 890  32.0   NaN        Q
#
# [891 rows x 3 columns]

# %%
train_df[['Age', 'Cabin', 'Embarked']].dropna()
# Out:
#       Age        Cabin Embarked
# 1    38.0          C85        C
# 3    35.0         C123        S
# 6    54.0          E46        S
# 10    4.0           G6        S
# 11   58.0         C103        S
# ..    ...          ...      ...
# 871  47.0          D35        S
# 872  33.0  B51 B53 B55        S
# 879  56.0          C50        C
# 887  19.0          B42        S
# 889  26.0         C148        C
#
# [183 rows x 3 columns]

# %%
train_df[['Survived', 'PassengerId', 'Embarked']].dropna().groupby(['Embarked', 'Survived']).count()
# Out:
#                    PassengerId
# Embarked Survived
# C        0                  75
#          1                  93
# Q        0                  47
#          1                  30
# S        0                 427
#          1                 217

# %%
train_df[['Pclass', 'PassengerId', 'Survived']].groupby(['Pclass', 'Survived']).count()
# Out:
#                  PassengerId
# Pclass Survived
# 1      0                  80
#        1                 136
# 2      0                  97
#        1                  87
# 3      0                 372
#        1                 119

# %%
embarked_df = train_df[["Embarked","Survived","PassengerId"]].dropna().groupby(["Embarked","Survived"]).count().unstack()
embarked_df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='Embarked'>

# %%
train_corr = train_df.corr()

# %%
plt.figure(figsize=(9, 9))
sns.heatmap(train_corr, vmax=1, vmin=-1, center=0, annot=True)
# Out:
# <AxesSubplot:>

# %%
pd.get_dummies(train_df['Sex'])
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]

# %%
train_df_corr = pd.get_dummies(train_df, columns=['Sex'], drop_first=True)
train_df_corr = pd.get_dummies(train_df_corr, columns=['Embarked'])

# %%
train_df_corr
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
all_df = pd.concat([train_df, test_df], sort=False).reset_index(drop=True)

# %%
all_df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
test_df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
Fare_mean = all_df[['Pclass', 'Fare']].groupby("Pclass").mean().reset_index()

# %%
all_df = pd.merge(all_df, Fare_mean, on='Pclass', how='left')

# %%
all_df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
all_df.loc[(all_df['Fare_x'].isnull()), 'Fare_x'] = all_df['Fare_y']

# %%
test_df.loc[test_df['Fare'].isnull(), 'Fare'] = test_df['Fare'].mean()

# %%
test_df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# dtype: int64

# %%
all_df['Name'].head(5)
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
all_df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
all_df = all_df.rename(columns={'Fare_x':'Fare'})
all_Df = all_df.drop(['Fare_y'], axis=1)

# %%
name_df = all_df['Name'].str.split("[,.]", 2, expand=True)

# %%
name_df.columns = ['family', 'honor', 'name']

# %%
name_df
# Out:
#              family    honor                                    name
# 0            Braund       Mr                             Owen Harris
# 1           Cumings      Mrs   John Bradley (Florence Briggs Thayer)
# 2         Heikkinen     Miss                                   Laina
# 3          Futrelle      Mrs           Jacques Heath (Lily May Peel)
# 4             Allen       Mr                           William Henry
# ...             ...      ...                                     ...
# 1304        Spector       Mr                                   Woolf
# 1305  Oliva y Ocana     Dona                                 Fermina
# 1306        Saether       Mr                         Simon Sivertsen
# 1307           Ware       Mr                               Frederick
# 1308          Peter   Master                               Michael J
#
# [1309 rows x 3 columns]

# %%
name_df['family'] = name_df['family'].str.strip()
name_df['honor'] = name_df['honor'].str.strip()
name_df['name'] = name_df['name'].str.strip()

# %%
name_df['honor'].value_counts()
# Out:
# Mr              757
# Miss            260
# Mrs             197
# Master           61
# Rev               8
# Dr                8
# Col               4
# Mlle              2
# Major             2
# Ms                2
# Lady              1
# Sir               1
# Mme               1
# Don               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Dona              1
# Name: honor, dtype: int64

# %%
all_df = pd.concat([all_df, name_df], axis = 1)

# %%
plt.figure(figsize=(18, 5))
sns.boxplot(x='honor', y='Age', data=all_df)
# Out:
# <AxesSubplot:xlabel='honor', ylabel='Age'>

# %%
all_df[['Age', 'honor']].groupby('honor').mean()
# Out:
#                     Age
# honor
# Capt          70.000000
# Col           54.000000
# Don           40.000000
# Dona          39.000000
# Dr            43.571429
# Jonkheer      38.000000
# Lady          48.000000
# Major         48.500000
# Master         5.482642
# Miss          21.774238
# Mlle          24.000000
# Mme           24.000000
# Mr            32.252151
# Mrs           36.994118
# Ms            28.000000
# Rev           41.250000
# Sir           49.000000
# the Countess  33.000000

# %%
train_df = pd.concat([train_df, name_df[:len(train_df)].reset_index(drop=True)], axis=1)
test_df = pd.concat([test_df, name_df[len(train_df):].reset_index(drop=True)], axis=1)

# %%
honor_df = train_df[['honor', 'Survived', 'PassengerId']].dropna().groupby(['honor', 'Survived']).count().unstack()

# %%
honor_df
# Out:
#              PassengerId
# Survived               0      1
# honor
# Capt                 1.0    NaN
# Col                  1.0    1.0
# Don                  1.0    NaN
# Dr                   4.0    3.0
# Jonkheer             1.0    NaN
# Lady                 NaN    1.0
# Major                1.0    1.0
# Master              17.0   23.0
# Miss                55.0  127.0
# Mlle                 NaN    2.0
# Mme                  NaN    1.0
# Mr                 436.0   81.0
# Mrs                 26.0   99.0
# Ms                   NaN    1.0
# Rev                  6.0    NaN
# Sir                  NaN    1.0
# the Countess         NaN    1.0

# %%
honor_df.plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='honor'>

# %%
honor_age_mean = all_df[['honor', 'Age']].groupby('honor').mean().reset_index()
honor_age_mean.columns = ['honor', 'honor_age']
all_df = pd.merge(all_df, honor_age_mean, on='honor', how='left')
all_df.loc[(all_df['Age'].isnull()), 'Age'] = all_df['honor_age']
all_df = all_df.drop(['honor_age'], axis=1)

# %%
all_df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %%
all_df['family_num'] = all_df['Parch'] + all_df['SibSp']
all_df['family_num'].value_counts()
# Out:
# 0     790
# 1     235
# 2     159
# 3      43
# 5      25
# 4      22
# 6      16
# 10     11
# 7       8
# Name: family_num, dtype: int64

# %%
all_df.loc[all_df['family_num']==0, 'alone'] = 1
all_df['alone'].fillna(0, inplace=True)

# %%
all_df['alone'] = all_df['alone'].astype('int')

# %%
all_df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %%
all_df = all_df.drop(['PassengerId', 'Name', 'family', 'name', 'Ticket', 'Cabin'], axis=1)

# %%
all_df
# Out:
#       Survived  Pclass     Sex        Age  SibSp  Parch      Fare Embarked  \
# 0          0.0       3    male  22.000000      1      0    7.2500        S
# 1          1.0       1  female  38.000000      1      0   71.2833        C
# 2          1.0       3  female  26.000000      0      0    7.9250        S
# 3          1.0       1  female  35.000000      1      0   53.1000        S
# 4          0.0       3    male  35.000000      0      0    8.0500        S
# ...        ...     ...     ...        ...    ...    ...       ...      ...
# 1304       NaN       3    male  32.252151      0      0    8.0500        S
# 1305       NaN       1  female  39.000000      0      0  108.9000        C
# 1306       NaN       3    male  38.500000      0      0    7.2500        S
# 1307       NaN       3    male  32.252151      0      0    8.0500        S
# 1308       NaN       3    male   5.482642      1      1   22.3583        C
#
#          Fare_y   honor  family_num  alone
# ...

# %%
categories = all_df.columns[all_df.dtypes == 'object']

# %%
categories
# Out:
# Index(['Sex', 'Embarked', 'honor'], dtype='object')

# %%
all_df.loc[~((all_df['honor'] == 'Mr') | (all_df['honor'] == 'Miss') | (all_df['honor'] == 'Mrs') | (all_df['honor'] == 'Master')), 'honor'] = 'other'

# %%
all_df
# Out:
#       Survived  Pclass     Sex        Age  SibSp  Parch      Fare Embarked  \
# 0          0.0       3    male  22.000000      1      0    7.2500        S
# 1          1.0       1  female  38.000000      1      0   71.2833        C
# 2          1.0       3  female  26.000000      0      0    7.9250        S
# 3          1.0       1  female  35.000000      1      0   53.1000        S
# 4          0.0       3    male  35.000000      0      0    8.0500        S
# ...        ...     ...     ...        ...    ...    ...       ...      ...
# 1304       NaN       3    male  32.252151      0      0    8.0500        S
# 1305       NaN       1  female  39.000000      0      0  108.9000        C
# 1306       NaN       3    male  38.500000      0      0    7.2500        S
# 1307       NaN       3    male  32.252151      0      0    8.0500        S
# 1308       NaN       3    male   5.482642      1      1   22.3583        C
#
#          Fare_y   honor  family_num  alone
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
all_df['Embarked'].fillna('missing', inplace=True)

# %%
le = LabelEncoder()
le = le.fit(all_df['Sex'])
all_df['Sex'] = le.transform(all_df['Sex'])

# %%
all_df
# Out:
#       Survived  Pclass  Sex        Age  SibSp  Parch      Fare Embarked  \
# 0          0.0       3    1  22.000000      1      0    7.2500        S
# 1          1.0       1    0  38.000000      1      0   71.2833        C
# 2          1.0       3    0  26.000000      0      0    7.9250        S
# 3          1.0       1    0  35.000000      1      0   53.1000        S
# 4          0.0       3    1  35.000000      0      0    8.0500        S
# ...        ...     ...  ...        ...    ...    ...       ...      ...
# 1304       NaN       3    1  32.252151      0      0    8.0500        S
# 1305       NaN       1    0  39.000000      0      0  108.9000        C
# 1306       NaN       3    1  38.500000      0      0    7.2500        S
# 1307       NaN       3    1  32.252151      0      0    8.0500        S
# 1308       NaN       3    1   5.482642      1      1   22.3583        C
#
#          Fare_y   honor  family_num  alone
# 0     13.302889      Mr           1      0
# ...

# %%
for cat in categories:
    le = LabelEncoder()
    print(cat)
    if all_df[cat].dtypes == 'object':
        le = le.fit(all_df[cat])
        all_df[cat] = le.transform(all_df[cat])
# Out:
# Sex
# Embarked
# honor

# %%
all_df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked     Fare_y  \
# 0       0.0       3    1  22.0      1      0   7.2500         2  13.302889
# 1       1.0       1    0  38.0      1      0  71.2833         0  87.508992
# 2       1.0       3    0  26.0      0      0   7.9250         2  13.302889
# 3       1.0       1    0  35.0      1      0  53.1000         2  87.508992
# 4       0.0       3    1  35.0      0      0   8.0500         2  13.302889
#
#    honor  family_num  alone
# 0      2           1      0
# 1      3           1      0
# 2      1           0      1
# 3      3           1      0
# 4      2           0      1

# %%
train_X = all_df[~all_df['Survived'].isnull()].drop('Survived', axis=1).reset_index(drop=True)
train_Y = all_df['Survived']

# %%
test_X = all_df[all_df['Survived'].isnull()].drop('Survived', axis=1).reset_index(drop=True)

# %%
train_X
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked     Fare_y  \
# 0         3    1  22.000000      1      0   7.2500         2  13.302889
# 1         1    0  38.000000      1      0  71.2833         0  87.508992
# 2         3    0  26.000000      0      0   7.9250         2  13.302889
# 3         1    0  35.000000      1      0  53.1000         2  87.508992
# 4         3    1  35.000000      0      0   8.0500         2  13.302889
# ..      ...  ...        ...    ...    ...      ...       ...        ...
# 886       2    1  27.000000      0      0  13.0000         2  21.179196
# 887       1    0  19.000000      0      0  30.0000         2  87.508992
# 888       3    0  21.774238      1      2  23.4500         2  13.302889
# 889       1    1  26.000000      0      0  30.0000         0  87.508992
# 890       3    1  32.000000      0      0   7.7500         1  13.302889
#
#      honor  family_num  alone
# 0        2           1      0
# 1        3           1      0
# ...
